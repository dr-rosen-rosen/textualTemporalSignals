# %%
import pandas as pd

# %%
df = pd.read_parquet('/Users/mrosen44/Documents/data_analysis_local/textualTemporalSignals/scripts/data/processed/phmsa/phmsa_full.parquet')

# %%
df.head()
# Out:
#                                           narrative1  \
# 0  A pallet arrived with 3 cartons punctured and ...
# 1  The cause of release was reportedly due to dam...
# 2  Associate did not block and/or brace freight p...
# 3  Associate punctured freight with forklift blad...
# 4  I WAS CALLED TO RESPOND TO A WET PKG. I DONNED...
#
#                                           narrative2  damages_over_500  \
# 0  Provide more training to dock personnel on pro...             False
# 1         Additional in-house training was provided.             False
# 2  All product was absorbed with oil dry and plac...             False
# 3  Responsible associate has been shown proper fr...             False
# 4                            NO DESCRIPTION PROVIDED             False
#
#    fatalities_caused_by_hazmat  injuries_caused_by_hazmat  \
# 0                        False                      False
# 1                        False                      False
# ...
